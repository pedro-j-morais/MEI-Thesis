# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/mad/code/SPL-MAD/EER\ Analysis/analyse_logs.py "/content/drive/MyDrive/mad/code/SPL-MAD/EER Analysis/logs_testing_smdd.txt" "normal" "crop"
# Out:
# === EER Statistics Per Algorithm ===
#
# normal:
#   Mean EER: 14.20%
#   Median EER: 13.71%
#   Min EER: 12.63%
#   Max EER: 18.11%
#   Std Dev: 1.62%
#
# crop:
#   Mean EER: 11.38%
#   Median EER: 10.81%
#   Min EER: 9.68%
#   Max EER: 15.49%
#   Std Dev: 1.81%
# Figure(1200x600)

# %%
# !python /content/drive/MyDrive/mad/code/SPL-MAD/EER\ Analysis/analyse_logs.py "/content/drive/MyDrive/mad/code/SPL-MAD/EER Analysis/logs_testing_frll-morphs.txt" "morph_amsl" "morph_facemorpher" "morph_opencv" "morph_stylegan" "morph_webmorph"
# Out:
# === EER Statistics Per Algorithm ===
#
# morph_amsl:
#   Mean EER: 33.31%
#   Median EER: 35.72%
#   Min EER: 16.23%
#   Max EER: 37.66%
#   Std Dev: 5.33%
#
# morph_facemorpher:
#   Mean EER: 7.05%
#   Median EER: 8.10%
#   Min EER: 0.49%
#   Max EER: 9.74%
#   Std Dev: 2.54%
#
# morph_opencv:
#   Mean EER: 7.87%
#   Median EER: 8.93%
#   Min EER: 0.98%
#   Max EER: 11.14%
#   Std Dev: 2.88%
#
# morph_stylegan:
#   Mean EER: 16.52%
#   Median EER: 17.35%
#   Min EER: 8.43%
#   Max EER: 19.15%
#   Std Dev: 2.74%
#
# morph_webmorph:
#   Mean EER: 27.82%
#   Median EER: 30.14%
#   Min EER: 10.40%
#   Max EER: 33.50%
#   Std Dev: 5.78%
# Figure(1200x600)
