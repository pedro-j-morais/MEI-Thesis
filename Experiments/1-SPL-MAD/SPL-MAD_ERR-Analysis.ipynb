# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/mad/code/SPL-MAD/EER\ Analysis/analyse_logs.py "SMDD" "/content/drive/MyDrive/mad/code/SPL-MAD/EER Analysis/logs_testing_smdd.txt" "normal" "crop"

from IPython.display import Image
Image("eer_trends_SMDD.png")
# Out:
# === EER Statistics Per Algorithm (SMDD) ===
#
# normal:
#   Mean EER: 14.20%
#   Median EER: 13.71%
#   Min EER: 12.63%
#   Max EER: 18.11%
#   Std Dev: 1.62%
#
# crop:
#   Mean EER: 11.38%
#   Median EER: 10.81%
#   Min EER: 9.68%
#   Max EER: 15.49%
#   Std Dev: 1.81%
#
# === Last Epoch Results ===
# Epoch 25 - normal EER: 12.63%
# Epoch 25 - crop EER: 9.68%
# Plot saved as eer_trends_SMDD.png

# %%
# !python /content/drive/MyDrive/mad/code/SPL-MAD/EER\ Analysis/analyse_logs.py "FRLL-Morphs" "/content/drive/MyDrive/mad/code/SPL-MAD/EER Analysis/logs_testing_frll-morphs.txt" "morph_amsl" "morph_facemorpher" "morph_opencv" "morph_stylegan" "morph_webmorph"

from IPython.display import Image
Image("eer_trends_FRLL-Morphs.png")
# Out:
# === EER Statistics Per Algorithm (FRLL-Morphs) ===
#
# morph_amsl:
#   Mean EER: 33.31%
#   Median EER: 35.72%
#   Min EER: 16.23%
#   Max EER: 37.66%
#   Std Dev: 5.33%
#
# morph_facemorpher:
#   Mean EER: 7.05%
#   Median EER: 8.10%
#   Min EER: 0.49%
#   Max EER: 9.74%
#   Std Dev: 2.54%
#
# morph_opencv:
#   Mean EER: 7.87%
#   Median EER: 8.93%
#   Min EER: 0.98%
#   Max EER: 11.14%
#   Std Dev: 2.88%
#
# morph_stylegan:
#   Mean EER: 16.52%
#   Median EER: 17.35%
#   Min EER: 8.43%
#   Max EER: 19.15%
#   Std Dev: 2.74%
#
# morph_webmorph:
#   Mean EER: 27.82%
#   Median EER: 30.14%
#   Min EER: 10.40%
#   Max EER: 33.50%
#   Std Dev: 5.78%
#
# === Last Epoch Results ===
# Epoch 25 - morph_amsl EER: 35.72%
# Epoch 25 - morph_facemorpher EER: 7.86%
# Epoch 25 - morph_opencv EER: 10.32%
# Epoch 25 - morph_stylegan EER: 16.86%
# Epoch 25 - morph_webmorph EER: 32.35%
# Plot saved as eer_trends_FRLL-Morphs.png

# %%
from google.colab import runtime
runtime.unassign()
